# %%
from ecmwfapi import ECMWFDataServer

# %%
server = ECMWFDataServer()

# %%
server.retrieve({
    "class": "ei",
    "dataset":"interim",
    "date":"2010-01-01/to/2010-12-31",
    "expver": "1",
    "grid":"0.25/0.25",
    "levtype":"sfc",
    "param": "159.128",
    "step":"3/6/9/12",
    "stream":"oper",
    "time":"00:00:00/12:00:00",
    "type":"fc",
    "area":"33.75/78.50/33.75/78.50",
    "format":"netcdf",
    "target":"erai_merak3.nc"
})
# Out:
# 2019-06-19 19:17:02 ECMWF API python library 1.4.0
# 2019-06-19 19:17:02 ECMWF API at https://api.ecmwf.int/v1
# 2019-06-19 19:17:03 Welcome Sachin P
# 2019-06-19 19:17:04 In case of problems, please check https://confluence.ecmwf.int/display/WEBAPI/Web-API+Troubleshooting or contact servicedesk@ecmwf.int. In case of delays, please check  service activity page https://apps.ecmwf.int/webapi-activity/
# 2019-06-19 19:17:04 Request is submitted
# 2019-06-19 19:17:06 Request is queued
# Calling 'nice mars /tmp/4e/49/tmp-_marsApt3DU.req'
# mars - WARN -
# mars - WARN - From 29 January 2019 10AM (UTC) MARS uses the interpolation
# mars - WARN - provided by the MIR library. For more details, see
# mars - WARN - https://confluence.ecmwf.int/display/UDOC/MARS+interpolation+with+MIR
# mars - WARN -
# PPDIR is /var/tmp/ppdir/x86_64
# mars - INFO   - 20190619.134816 - Welcome to MARS
# mars - INFO   - 20190619.134816 - MARS Client build stamp: 20190607111047
# ...
